# %%
#import necessary packages
import platform
import os
import sys
import time
#for managing the data
import pandas as pd

#install !pip install webdriver-manager
#webdrivers
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup

# %%
#data prefix for output data
yearmonth = "202404"

# %%
#open web driver
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
#url
base_url_list = \
[
    ['Food Premisis',"https://checkbeforeyougo.phsd.ca/FoodPremises/Table", ['Facility Name','Site Address','Facility Type','Last Inspection Date']],
    ['Personal Services Settings',"https://checkbeforeyougo.phsd.ca/PersonalServicesSettings/Table", ['Facility Name','Site Address','Services Inspected','Last Inspection Date']],
    ['Child Care Settings',"https://checkbeforeyougo.phsd.ca/ChildCareSettings/Table", ['Facility Name','Site Address','Last Inspection Date']],
    ['Pools, Spas, Splash Pads',"https://checkbeforeyougo.phsd.ca/PoolsSpasSplashPads/Table",['Facility Name','Site Address','Facility Type','Last Inspection Date']],
    ['Beaches',"https://checkbeforeyougo.phsd.ca/Beaches/Table",['Facility Name','Site Address','Last Inspection Date']],
    ['Drinking Water',"https://checkbeforeyougo.phsd.ca/DrinkingWater/Table",['Facility Name','Site Address','Last Inspection Date']],
    ['Recreational Camps',"https://checkbeforeyougo.phsd.ca/RecreationalCamps/Table",['Facility Name','Site Address','Last Inspection Date']],
    ['Convictions, Orders and Advisories',"https://checkbeforeyougo.phsd.ca/Enforcements",['Facility Name','Site Address','Type','Offense','Outcome','Offense Date','Comment','Resolved Date']],
]

# %%
#place holder for final dataframe list
df_list = []

for u in base_url_list:
    category = u[0]
    base_url = u[1]
    columns  = u[2]

    #load main landing page
    driver.get(base_url)
    
    try:
        #find disclaimer button
        disclamer_btn = driver.find_element(by='name', value="AcceptDisclaimerButton")

        #click the disclaimer button to move to the data page
        disclamer_btn.click()
    except:
        pass
    
    # We will loop through until there's no next page button on the webpage
    #find next page button
    last_page = False

    while last_page==False:
        try:
            next_btn = driver.find_element(By.CLASS_NAME, value="next-page-link")
        except:
            last_page = True


        #place holder for extracted data
        data_url_list = []

        #locate each table rows
        data_rows = driver.find_elements(By.CLASS_NAME, value="hovereffect")

        for row in data_rows:
            data_url_list.append( row.get_attribute("onclick") )

        #convert html table into dataframe
        df = pd.read_html(driver.page_source)
        df = df[0]
        

        #rename columns for clean up
        df.columns = columns
        
        #append url column and category column
        df['url'] = data_url_list
        df['category'] = category

        #put aside resulting table
        df_list.append(df)

        if last_page==True:
            break
        #move to the next page
        next_btn.click()
# Out:
# C:\Users\nanil\AppData\Local\Temp\ipykernel_31148\4001557055.py:42: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(driver.page_source)
# C:\Users\nanil\AppData\Local\Temp\ipykernel_31148\4001557055.py:42: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(driver.page_source)
# C:\Users\nanil\AppData\Local\Temp\ipykernel_31148\4001557055.py:42: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(driver.page_source)
# ...

# %%
final_df = pd.concat(df_list)

# %%
final_df.to_csv( "../data/{}_1st_table.csv".format(yearmonth) )

# %%
#close webdriver
try:
    driver.close()
except:
    pass

# %%
final_df
# Out:
#                                         Facility Name  \
# 0   2 Legged Bear Mobile Food Cart - Mobile Food Cart
# 1                                     3 Cows & A Cone
# 2                                        3 Cows Fries
# 3                              5 Fish Resort & Marina
# 4   540 Ends General store (formerly: The Olde Cou...
# ..                                                ...
# 21                                    Wanikewin Lodge
# 22                                   Waterfalls Lodge
# 23                         Windy Lake Provincial Park
# 24                         Windy Lake Provincial Park
# 0                          Windy Lake Provincial Park
#
#                                          Site Address  \
# 0               25965 Hwy 540  Meldrum Bay ON P0P 1R0
# 1   64 Meredith Street East  Little Current ON P0P...
# 2       64 Meredith Street  Little Current ON P0P 1K0
# 3                25 Whippoorwill Rd  Alban ON P0M 1A0
# ...
