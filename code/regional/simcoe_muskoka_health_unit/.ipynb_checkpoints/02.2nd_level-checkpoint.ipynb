# %%
#data prefix for output data
yearmonth = "202405"

# %%
#import necessary packages
import platform
import os
import sys
import time
#for managing the data
import pandas as pd

#install !pip install webdriver-manager
#webdrivers
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup

import pathlib

import os
from io import StringIO

from tqdm import tqdm

# %%
#get current path
curr_path = os.getcwd()
project_tag = curr_path.split("/")[-1]
grouping = curr_path.split("/")[-2]
output_path = "../../../data/{}/{}/{}/".format(grouping,project_tag,yearmonth )

#create data output path if it doesn't exist
pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
#load in level 1 data
df = pd.read_csv(output_path + "1_level_table.csv")
print(df.shape)
# Out:
# (6845, 13)

# %%
#open web driver
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
#place holder for final dataframe list
df_list = []

# %%
for i,r in tqdm( df.iterrows() ):
    #resume point in case it crashes
    last_i = len(df_list)-1
    if i<last_i:
        continue
    url = r['url_entity_partial']
    url_entity = r['url_entity_full']
    
    #load the main landing page
    driver.get(url_entity)
    
    try:
        #find disclaimer button
        disclamer_btn = driver.find_element(by='name', value="AcceptDisclaimerButton")
    
        #click the disclaimer button to move to the data page
        disclamer_btn.click()
    except:
        pass

    #place holder for extracted data
    data_url_list = []
    data_url_full_list = []
    
    #locate each table rows
    data_rows = driver.find_elements(By.CLASS_NAME, value="hovereffect")

    #if no inspection data skip to the next url
    if len(data_rows)==0:
        continue
    
    for row in data_rows:
        data_url_list.append( row.get_attribute("onclick") )
    
    url_prefix = "https://simcoeportal.hedgerowsoftware.com"
    for u in data_url_list:
        temp_url = url_prefix+u.split("'")[1]
        data_url_full_list.append(temp_url)
    
    tables = pd.read_html(StringIO((driver.page_source)))
    table  = tables[1]
    table['url_inspection'] = data_url_list
    table['url_inspection_full'] = data_url_full_list
    table['url_entity_full'] = url_entity

    df_list.append(table)
# Out:
# 6845it [49:42,  2.30it/s]

# %%
final_df = pd.concat(df_list)
print(final_df.shape)
# Out:
# (18521, 7)

# %%
final_df
# Out:
#    Inspection Date Inspection Type  Critical Infractions Count  \
# 0      13-Jan-2023         Routine                           0
# 0      16-Oct-2023         Routine                           1
# 1      25-Jan-2023         Routine                           0
# 2      08-Jun-2022         Routine                           1
# 0      15-Feb-2024         Routine                           1
# ..             ...             ...                         ...
# 5      16-Mar-2023         Routine                           2
# 6      03-Nov-2022         Routine                           0
# 7      27-Jul-2022         Routine                           1
# 8      01-Mar-2022       Follow-up                           0
# 9      28-Feb-2022         Routine                           0
#
#     Non Critical Infractions Count  \
# 0                                0
# 0                                1
# 1                                0
# 2                                0
# 0                                1
# ..                             ...
# 5                                1
# 6                                1
# 7                                1
# 8                                1
# 9                                1
#
#                                        url_inspection  \
# 0   location.href = '/Inspection/Details/bc8812df-...
# 0   location.href = '/Inspection/Details/aae88ed3-...
# 1   location.href = '/Inspection/Details/0e3c4c06-...
# 2   location.href = '/Inspection/Details/b07d3fcb-...
# 0   location.href = '/Inspection/Details/7b2040cc-...
# ..                                                ...
# 5   location.href = '/Inspection/Details/6c9e0f47-...
# 6   location.href = '/Inspection/Details/6e5cc3b9-...
# 7   location.href = '/Inspection/Details/547f113d-...
# 8   location.href = '/Inspection/Details/494a4adb-...
# 9   location.href = '/Inspection/Details/545ccd3c-...
#
#                                   url_inspection_full  \
# 0   https://simcoeportal.hedgerowsoftware.com/Insp...
# 0   https://simcoeportal.hedgerowsoftware.com/Insp...
# 1   https://simcoeportal.hedgerowsoftware.com/Insp...
# 2   https://simcoeportal.hedgerowsoftware.com/Insp...
# 0   https://simcoeportal.hedgerowsoftware.com/Insp...
# ..                                                ...
# 5   https://simcoeportal.hedgerowsoftware.com/Insp...
# 6   https://simcoeportal.hedgerowsoftware.com/Insp...
# 7   https://simcoeportal.hedgerowsoftware.com/Insp...
# 8   https://simcoeportal.hedgerowsoftware.com/Insp...
# 9   https://simcoeportal.hedgerowsoftware.com/Insp...
#
#                                       url_entity_full
# 0   https://simcoeportal.hedgerowsoftware.com/Faci...
# 0   https://simcoeportal.hedgerowsoftware.com/Faci...
# 1   https://simcoeportal.hedgerowsoftware.com/Faci...
# 2   https://simcoeportal.hedgerowsoftware.com/Faci...
# 0   https://simcoeportal.hedgerowsoftware.com/Faci...
# ..                                                ...
# 5   https://simcoeportal.hedgerowsoftware.com/Faci...
# 6   https://simcoeportal.hedgerowsoftware.com/Faci...
# 7   https://simcoeportal.hedgerowsoftware.com/Faci...
# 8   https://simcoeportal.hedgerowsoftware.com/Faci...
# 9   https://simcoeportal.hedgerowsoftware.com/Faci...
#
# [18521 rows x 7 columns]

# %%
final_df.to_csv( output_path + "2_level_table.csv", index=False)

# %%
#close webdriver
try:
    driver.close()
except:
    pass
