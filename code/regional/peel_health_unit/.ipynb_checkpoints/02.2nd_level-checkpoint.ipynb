# %%
#data prefix for output data
yearmonth = "202405"

# %%
#import necessary packages
import platform
import os
import sys
import time
#for managing the data
import pandas as pd

#install !pip install webdriver-manager
#webdrivers
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup

import pathlib

import os
from io import StringIO

from tqdm import tqdm

# %%
#get current path
curr_path = os.getcwd()
project_tag = curr_path.split("/")[-1]
grouping = curr_path.split("/")[-2]
output_path = "../../../data/{}/{}/{}/".format(grouping,project_tag,yearmonth )

#create data output path if it doesn't exist
pathlib.Path(output_path).mkdir(parents=True, exist_ok=True)

# %%
#load in level 1 data
df = pd.read_csv(output_path + "1_level_table.csv")
print(df.shape)
# Out:
# (9130, 8)

# %%
#open web driver
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
#place holder for final dataframe list
df_list = []

# %%
for i,r in tqdm( df.iterrows() ):
    #resume point in case it crashes
    last_i = len(df_list)-1
    if i<last_i:
        continue
    url = r['url_entity_partial']
    url_entity = r['url_entity_full']
    
    #load the main landing page
    driver.get(url_entity)
    
    try:
        #find disclaimer button
        disclamer_btn = driver.find_element(by='name', value="AcceptDisclaimerButton")
    
        #click the disclaimer button to move to the data page
        disclamer_btn.click()
    except:
        pass

    #place holder for extracted data
    data_url_list = []
    data_url_full_list = []
    
    #locate each table rows
    data_rows = driver.find_elements(By.CLASS_NAME, value="hovereffect")

    #if no inspection data skip to the next url
    if len(data_rows)==0:
        continue
    
    for row in data_rows:
        data_url_list.append( row.get_attribute("onclick") )
    
    url_prefix = "https://rmop.hedgerowsoftware.com"
    for u in data_url_list:
        temp_url = url_prefix+u.split("'")[1]
        data_url_full_list.append(temp_url)
    
    tables = pd.read_html(StringIO((driver.page_source)))
    table  = tables[1]
    table['url_inspection'] = data_url_list
    table['url_inspection_full'] = data_url_full_list
    table['url_entity_full'] = url_entity

    df_list.append(table)
# Out:
# 9130it [19:33,  7.78it/s]

# %%
final_df = pd.concat(df_list)
print(final_df.shape)
# Out:
# (25054, 7)

# %%
final_df
# Out:
#    Inspection Date Inspection Type  Inspection Result  \
# 0       2024-04-22        Required                NaN
# 1       2023-12-07        Required                NaN
# 2       2023-04-27        Required                NaN
# 0       2024-04-09        Required                NaN
# 1       2023-11-06        Required                NaN
# ..             ...             ...                ...
# 0       2024-02-20        Required                NaN
# 0       2023-02-17        Required                NaN
# 0       2023-05-15        Required                NaN
# 0       2022-06-07        Required                NaN
# 0       2024-04-19        Required                NaN
#
#                                        url_inspection  \
# 0   location.href = '/Portal/Inspection/Details/35...
# 1   location.href = '/Portal/Inspection/Details/cd...
# 2   location.href = '/Portal/Inspection/Details/07...
# 0   location.href = '/Portal/Inspection/Details/0d...
# 1   location.href = '/Portal/Inspection/Details/12...
# ..                                                ...
# 0   location.href = '/Portal/Inspection/Details/4f...
# 0   location.href = '/Portal/Inspection/Details/d4...
# 0   location.href = '/Portal/Inspection/Details/48...
# 0   location.href = '/Portal/Inspection/Details/99...
# 0   location.href = '/Portal/Inspection/Details/e0...
#
#                                   url_inspection_full  \
# 0   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 1   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 2   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 0   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 1   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# ..                                                ...
# 0   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 0   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 0   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 0   https://rmop.hedgerowsoftware.com/Portal/Inspe...
# 0   https://rmop.hedgerowsoftware.com/Portal/Inspe...
#
#                                       url_entity_full  \
# 0   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 1   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 2   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 0   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 1   https://rmop.hedgerowsoftware.com/Portal/Facil...
# ..                                                ...
# 0   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 0   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 0   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 0   https://rmop.hedgerowsoftware.com/Portal/Facil...
# 0   https://rmop.hedgerowsoftware.com/Portal/Facil...
#
#                           Facility Name
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 0                                   NaN
# 1                                   NaN
# ..                                  ...
# 0             Sol de Ora & Spa -Tanning
# 0           Sun Beach Tanning - Tanning
# 0         Sunbeach Wellness Clinic Ltd.
# 0    W.G. Brampton Fitness Inc. Tanning
# 0   Peel Urgent Public Health Need Site
#
# [25054 rows x 7 columns]

# %%
final_df.to_csv( output_path + "2_level_table.csv", index=False)

# %%
#close webdriver
try:
    driver.close()
except:
    pass
